# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamedZepcanin/MuhamedZepcanin/blob/main/quizz_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")

# %%
x= float(input('score: '))

if x>=100:

  grade = 'A'

elif x>=93 :

  grade = 'A'

elif x>=92:

  grade = 'A-'

elif x>=90:

  grade = 'A-'

elif x>=89:

  grade = 'B+'

elif x>=87:

  grade = 'B+'

elif x>=86:

  grade = 'B'

elif x>=83:

  grade = 'B'

elif x>=82:

  grade = 'B-'

elif x>=80:

  grade = 'B-'

elif x>=79:

  grade = 'C+'

elif x>=77:

  grade = 'C+'

elif x>=76:

  grade = 'C'

elif x>=73:

  grade = 'C'

elif x>=72:

  grade = 'C-'

elif x>=70:

  grade = 'C-'

elif x>=69:

  grade = 'D+'

elif x>=67:

  grade = 'D+'

elif x>=66:

  grade = 'D'

elif x>=63:

  grade = 'D'

elif x>=62:

  grade = 'D-'

elif x>=60:

  grade = 'D-'

elif x>=59:

  grade = 'F'

elif x>= 0:

  grade = 'F'

print(grade)
# Out:
# score: 100
# A

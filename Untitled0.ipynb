# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhamedZepcanin/MuhamedZepcanin.github.io/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("What is your name? ")
print("Hello,", name + "!")
# Out:
# What is your name? Muhamed
# Hello, Muhamed!

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Sum:", num1 + num2)
print("Difference:", num1 - num2)
print("Product:", num1 * num2)

if num2 != 0:
    print("Quotient:", num1 / num2)
else:
    print("Quotient: undefined (division by zero)")
# Out:
# Enter first number: 1
# Enter second number: 192
# Sum: 193.0
# Difference: -191.0
# Product: 192.0
# Quotient: 0.005208333333333333

# %%
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9/5) + 32

print("Temperature in Fahrenheit:", fahrenheit)
# Out:
# Enter temperature in Celsius: 201
# Temperature in Fahrenheit: 393.8
